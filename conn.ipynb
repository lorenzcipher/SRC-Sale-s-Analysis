# %%
import mysql.connector as cn
import pandas as pd

# %%
contosodb = cn.connect(
     host="localhost", user="root", password="ekedie", database="contoso_store"
)

data = pd.read_sql_query("select * from factsale limit 300000", contosodb)

data.head()
# Out:
# C:\Users\WEB3\AppData\Local\Temp\ipykernel_18472\764996278.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query("select * from factsale limit 300000", contosodb)
#    SalesKey    DateKey  SalesQuantity  ReturnQuantity  DiscountQuantity  \
# 0      7077 2015-04-13              9               1                 1
# 1      7078 2016-06-13             20               0                 0
# 2      7079 2016-10-31             13               0                 1
# 3      7080 2015-12-11             13               0                 2
# 4      7081 2014-04-15             18               0                 5
#
#    SaleAmount     COGS  ReturnAmount  ProfitAmount  ProfitMargin  \
# 0      2736.0  1258.20         304.0       1173.80      0.429020
# 1      1519.8   774.80           0.0        745.00      0.490196
# ...

# %%
import sqlite3

conn = sqlite3.connect('consoto.sqlite')
data.to_sql('consoto_store', conn, if_exists='replace', index=False)
conn.close()

# %%
conn = sqlite3.connect('consoto.sqlite')
df = pd.read_sql_query("select * from consoto_store limit 50000", conn)

df.head()
# Out:
#    SalesKey              DateKey  SalesQuantity  ReturnQuantity  \
# 0      7077  2015-04-13 00:00:00              9               1
# 1      7078  2016-06-13 00:00:00             20               0
# 2      7079  2016-10-31 00:00:00             13               0
# 3      7080  2015-12-11 00:00:00             13               0
# 4      7081  2014-04-15 00:00:00             18               0
#
#    DiscountQuantity  SaleAmount     COGS  ReturnAmount  ProfitAmount  \
# 0                 1      2736.0  1258.20         304.0       1173.80
# 1                 0      1519.8   774.80           0.0        745.00
# 2                 1      7787.0  3580.98           0.0       4206.02
# 3                 2      8151.0  2700.62           0.0       5450.38
# 4                 5      4122.0  1365.66           0.0       2756.34
#
#    ProfitMargin                     StoreName  ContinentName  \
# 0      0.429020    Contoso Moscow  No.2 Store         Europe
# ...

# %%
df.shape
# Out:
# (50000, 20)

# %%
df['DateKey'] = pd.to_datetime(df['DateKey'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SalesKey                50000 non-null  int64
#  1   DateKey                 50000 non-null  datetime64[ns]
#  2   SalesQuantity           50000 non-null  int64
#  3   ReturnQuantity          50000 non-null  int64
#  4   DiscountQuantity        50000 non-null  int64
#  5   SaleAmount              50000 non-null  float64
#  6   COGS                    50000 non-null  float64
#  7   ReturnAmount            50000 non-null  float64
#  8   ProfitAmount            50000 non-null  float64
#  9   ProfitMargin            50000 non-null  float64
#  10  StoreName               50000 non-null  object
#  11  ContinentName           50000 non-null  object
#  12  Region                  50000 non-null  object
#  13  States                  50000 non-null  object
# ...

# %%
conn.close()
